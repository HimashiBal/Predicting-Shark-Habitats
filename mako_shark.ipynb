# %% [markdown]
# <a href="https://colab.research.google.com/github/HimashiBal/Predicting-Shark-Habitats/blob/main/mako_shark.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = "/content/drive/MyDrive/SHARK DATA/Shortfin Mako Vaudo et al - raw data.csv"

df = pd.read_csv(path)
df1 = pd.DataFrame(df)
print(df1)
# Out:
#        shark            timestamp  longitude  latitude argos_location_class  \
# 0          1  2013-03-23 12:00:00  -86.29000  21.24000                    3
# 1          1  2013-03-23 19:23:36  -86.49730  21.41050                    2
# 2          1  2013-03-23 19:32:53  -86.50630  21.40160                    1
# 3          1  2013-03-23 21:04:34  -86.48880  21.45260                    3
# 4          1  2013-03-24 12:00:30  -86.47930  22.09690                    1
# ...      ...                  ...        ...       ...                  ...
# 25635     26  2015-08-26 20:22:00  -70.56629  41.10687                    B
# 25636     26  2015-08-26 22:56:00  -70.55428  41.05239                    2
# 25637     26  2015-08-27 06:30:00  -70.58535  40.95506                    A
# 25638     26  2015-08-31 21:59:00  -70.81768  40.82880                    B
# 25639     26  2015-08-31 23:04:00  -70.80026  40.84223                    B
#
#        Unnamed: 5
# 0             NaN
# ...

# %%
df1.head()
# Out:
#    shark            timestamp  longitude  latitude argos_location_class  \
# 0      1  2013-03-23 12:00:00   -86.2900   21.2400                    3
# 1      1  2013-03-23 19:23:36   -86.4973   21.4105                    2
# 2      1  2013-03-23 19:32:53   -86.5063   21.4016                    1
# 3      1  2013-03-23 21:04:34   -86.4888   21.4526                    3
# 4      1  2013-03-24 12:00:30   -86.4793   22.0969                    1
#
#    Unnamed: 5
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %% [markdown]
# https://colab.research.google.com/github/la-counts/data-adventures/blob/master/Instructable_6_How_to_Map_Geographic_Data_Using_Coordinates.ipynb

# %% [markdown]
# try to map the long/lat coordinates onto a map

# %%
# import plotly.plotly as py
# import plotly.figure_factory as ff
# import plotly.tools as tl
# import pandas as pd

# data = pd.read_csv("/content/drive/MyDrive/SHARK DATA/Shortfin Mako Vaudo et al - raw data.csv")


# tl.set_credentials_file(username='himashib', api_key='••••••••••')

# # 4. The below code selects columns 0 ("X", or longitude), 1 ("Y", or latitude), and 9 ("Name"), which we will use as label.
# # We'll only print the first 100 lines, since this is a big dataset!

# newdata = data.iloc[0:100, [0,1,9]]

# table = ff.create_table(newdata)
# py.iplot(table, filename='Los Angeles Public School Locations')

# %% [markdown]
# https://kanoki.org/python-plotting-latitude-and-longitude-from-csv-on-map-using-basemap-folium-geopandas-and-plotly

# %%
import plotly.express as px
import pandas as pd

# %%
# plotting map using plotly
fig = px.scatter_geo(df, lat = 'latitude', lon = 'longitude', color = 'shark')

# setting title for the map
fig.update_layout(title = 'Countries', title_x = 0.5)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
import geopandas as gpd
from geopandas import GeoDataFrame
from shapely.geometry import Point

# %%
geometry = [Point(xy) for xy in zip(df['longitude'], df['latitude'])]
gdf = GeoDataFrame(df, geometry = geometry)

# %%
# plotting naturalearth_lowres map
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
gdf.plot(ax = world.plot(figsize = (10, 10)), color = 'red', markersize = 0.0125)
# Out:
# <ipython-input-11-f5e1aeeca670>:2: FutureWarning:
#
# The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
# <Axes: >
